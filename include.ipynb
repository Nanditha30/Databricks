# %%
from pyspark.sql.functions import *

# %%
input_path="s3://jpmctraining/input_files"

# %%
def add_ingestion_col(df):
    df1=df.withColumn("ingestion_date",current_timestamp())
    return df1

# %%
# %sql
use catalog dev;
create schema if not exists nanditha_bronze;
create schema if not exists nanditha_silver;
create schema if not exists nanditha_gold;
