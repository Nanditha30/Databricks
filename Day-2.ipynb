# %%
# %sql
insert into dev.naval.emp values (10,"nanditha","Hyderabad");

# %%
# %run "/Workspace/Users/nandithavelagandula3@gmail.com/Databricks/include"

# %%
dbutils.widgets.text("file_name","sales")
dbutils.widgets.text("schema","nanditha_bronze")
tblname=dbutils.widgets.get("file_name")
schema=dbutils.widgets.get("schema")

# %%
df=spark.read.csv(f"{input_path}/{tblname}",header=True,inferSchema=True)

# %%
df1=add_ingestion_col(df)
df1.write.mode("overwrite").saveAsTable(f"{schema}.{tblname}")

# %%
df=spark.read.table("dev.nanditha_bronze.sales")
df1=df.dropDuplicates().dropna().drop("ingestion_date")
df1.write.mode("overwrite").saveAsTable("dev.nanditha_silver.sales_cleaned")

# %%
# %sql

create view dev.nanditha_gold.top_customer as 
select customer_id, round(sum(total_amount)) as total from dev.nanditha_silver.sales_cleaned group by customer_id order by total desc limit 3

# %%
# %sql
select * from dev.nanditha_gold.top_customer;
