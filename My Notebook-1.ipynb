# %% [markdown]
# NANDITHA'S NOTEBOOK

# %%
print("Welcome")

# %%
# %sql
use catalog dev;
create schema if not exists nanditha;
use schema nanditha;

# %%
# %sql
create table test (id int, name string);
insert into test values (1, 'nanditha');
select * from test

# %%
# %sql
CREATE OR REPLACE FUNCTION dev.nanditha.return_name(x int)
RETURNS STRING
RETURN (SELECT name FROM dev.nanditha.test WHERE id = x LIMIT 1);

SELECT return_name(1);

# %%
# %sql
create table dev.nanditha.data as 
select * from json.`path to json file`

# %%
# %sql
create or replace table dev.nanditha.financial_data as
select *, current_date() as ingestion_date from read_files("/Volumes/dev/naval/raw/financial_dataset.csv",format=>"csv")

# %%
# %sql
select * from dev.nanditha.financial_data;

# %%
# %sql
create or replace table dev.nanditha.medical_data as 
select * from json.`/Volumes/dev/naval/raw/1.json`

# %%
# %sql
select * from dev.nanditha.medical_data;

# %% [markdown]
# Task:
#
# Step 1: create a Dataframe by read the csv file
# Step 2: Tranformation
#         - i. rename TransactionID to transaction_id
#         - ii. rename CustomerID to customer_id
#         - iii. add new col ingestion_date using current_timestamp
#         - iv. add new col metadata using _metadatat.filename
# Step 3: save it to a table

# %%
from pyspark.sql.types import *
schema = StructType([
    StructField("TransactionID", StringType(), True),
    StructField("CustomerID", StringType(), True),
    StructField("AccountType", StringType(), True),
    StructField("TransactionType", StringType(), True),
    StructField("AmountUSD", DoubleType(), True),
    StructField("Branch", StringType(), True),
    StructField("TransactionDate", DateType(), True)
])

# %%
df=spark.read.schema(schema).csv("/Volumes/dev/naval/raw/financial_dataset.csv", header=True)

# %%
from pyspark.sql.functions import current_timestamp

# %%
df1 = df.withColumnRenamed("TransactionID", "transaction_id") \
        .withColumnRenamed("CustomerID", "customer_id") \
        .withColumn("ingestion_date", current_timestamp())

# %%
df1.write.mode("overwrite").saveAsTable("dev.nanditha.financial_py")

# %%
# %sql
select * from dev.nanditha.financial_py;

# %% [markdown]
# Dummy commit and push
